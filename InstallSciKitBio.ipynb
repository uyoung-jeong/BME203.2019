# %% [markdown]
# <a href="https://colab.research.google.com/github/taejoonlab/BME203.2019/blob/master/InstallSciKitBio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install scikit-bio (and other library) using apt
# * A virtual machine behind colab notebook is a linux system ([ubuntu](https://www.ubuntu.com))
# * You can find a package for this method at https://packages.ubuntu.com/.

# %%
# !apt-get update
# !apt-get install python3-skbio python-skbio-doc
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# ...

# %%
from skbio import TabularMSA, DNA
from skbio.alignment import local_pairwise_align_ssw

# Example from http://scikit-bio.org/docs/latest/alignment.html

alignment, score, start_end_positions = local_pairwise_align_ssw( DNA("ACTAAGGCTCTCTACCCCTCTCAGAGA"), DNA("ACTAAGGCTCCTAACCCCCTTTTCTCAGA") )
print(alignment)
# Out:
# TabularMSA[DNA]
# ------------------------------
# Stats:
#     sequence count: 2
#     position count: 30
# ------------------------------
# ACTAAGGCTCTC-TACCC----CTCTCAGA
# ACTAAGGCTC-CTAACCCCCTTTTCTCAGA

# %% [markdown]
# # Install scikit-bio (and other library) using conda
#
# *  https://www.anaconda.com/ Anaconda is a great cross-platform system to install python and other tools.

# %%
# !wget -c https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# !chmod +x Anaconda3-5.1.0-Linux-x86_64.sh
# !ls
# Out:
# --2019-03-03 01:24:50--  https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 577996269 (551M) [application/x-sh]
# Saving to: ‘Anaconda3-5.1.0-Linux-x86_64.sh’
#
# Anaconda3-5.1.0-Lin 100%[===================>] 551.22M   169MB/s    in 3.3s
#
# 2019-03-03 01:24:59 (168 MB/s) - ‘Anaconda3-5.1.0-Linux-x86_64.sh’ saved [577996269/577996269]
#
# Anaconda3-5.1.0-Linux-x86_64.sh  sample_data

# %%
## Installing Anaconda (it takes quite a long time.)
# !bash ./Anaconda3-5.1.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -c https://conda.anaconda.org/biocore scikit-bio
# Out:
# PREFIX=/usr/local
# installing: python-3.6.4-hc3d631a_1 ...
# Python 3.6.4 :: Anaconda, Inc.
# installing: ca-certificates-2017.08.26-h1d4fec5_0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: intel-openmp-2018.0.0-hc7b2577_8 ...
# installing: libgcc-ng-7.2.0-h7cc24e2_2 ...
# installing: libgfortran-ng-7.2.0-h9f7466a_2 ...
# installing: libstdcxx-ng-7.2.0-h7a57d05_2 ...
# installing: bzip2-1.0.6-h9a117a8_4 ...
# installing: expat-2.2.5-he0dffb1_0 ...
# installing: gmp-6.1.2-h6c8ec71_1 ...
# installing: graphite2-1.3.10-hf63cedd_1 ...
# installing: icu-58.2-h9c2bf20_1 ...
# installing: jbig-2.1-hdba287a_0 ...
# installing: jpeg-9b-h024ee3a_2 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: libsodium-1.0.15-hf101ebd_0 ...
# installing: libtool-2.4.6-h544aabb_3 ...
# installing: libxcb-1.12-hcd93eb1_4 ...
# installing: lzo-2.10-h49e0be7_2 ...
# installing: mkl-2018.0.1-h19d6760_4 ...
# installing: ncurses-6.0-h9df7e31_2 ...
# ...

# %%
# Setting the path for the library
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages/')

# Load the scikit-bio modules
from skbio import TabularMSA, DNA
from skbio.alignment import local_pairwise_align_ssw

# Example from http://scikit-bio.org/docs/latest/alignment.html

alignment, score, start_end_positions = local_pairwise_align_ssw( DNA("ACTAAGGCTCTCTACCCCTCTCAGAGA"), DNA("ACTAAGGCTCCTAACCCCCTTTTCTCAGA") )
print(alignment)
# Out:
# TabularMSA[DNA]
# ------------------------------
# Stats:
#     sequence count: 2
#     position count: 30
# ------------------------------
# ACTAAGGCTCTC-TACCC----CTCTCAGA
# ACTAAGGCTC-CTAACCCCCTTTTCTCAGA
